# %% [markdown]
# # Data2001 - Assignment 1: Group 59

# %% [markdown]
# ## Members:

# %% [markdown]
# 1. SID: 520447042
# 2. SID:
# 3. SID:
# 4. SID:

# %% [markdown]
# # Task 1:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Task 1: Load CSV File - COMPLETE

# %%
region = pd.read_csv("Region_summary_ New_South_ Wales_STE_1.csv")

# %% [markdown]
# ## Preview Dataset - Temporary

# %%
print(region)
# Out:
#     Measure Code                                 Parent Description  \
# 0       ERP_P_20  Estimated resident population - year ended 30 ...
# 1         ERP_21  Estimated resident population - year ended 30 ...
# 2       ERP_M_20  Estimated resident population - year ended 30 ...
# 3       ERP_F_20  Estimated resident population - year ended 30 ...
# 4         ERP_19  Estimated resident population - year ended 30 ...
# ..           ...                                                ...
# 795   LTENURE_10  Land tenure experimental estimates - year ende...
# 796   LTENURE_11  Land tenure experimental estimates - year ende...
# 797   LTENURE_12  Land tenure experimental estimates - year ende...
# 798   LTENURE_13  Land tenure experimental estimates - year ende...
# 799   LTENURE_14  Land tenure experimental estimates - year ende...
#
#                                        Description  2011  2015        2016  \
# 0              Estimated resident population (no.)   NaN   NaN         NaN
# 1                 Population density (persons/km2)   NaN   NaN         NaN
# 2      Estimated resident population - males (no.)   NaN   NaN         NaN
# 3    Estimated resident population - females (no.)   NaN   NaN         NaN
# 4                       Median age - males (years)   NaN   NaN         NaN
# ..                                             ...   ...   ...         ...
# 795                Multiple-use public forest (ha)   NaN   NaN   2189712.0
# 796                      Other Crown purposes (ha)   NaN   NaN   1591712.0
# 797                          Other Crown land (ha)   NaN   NaN    398088.0
# 798                Land tenure not classified (ha)   NaN   NaN    392450.0
# 799                         Total land tenure (ha)   NaN   NaN  80129856.0
#
#      2017  2018       2019       2020       2021       2022       2023  \
# 0     NaN   NaN  8046748.0  8110610.0  8097062.0  8166704.0  8341199.0
# 1     NaN   NaN       10.0       10.1       10.1       10.2       10.4
# 2     NaN   NaN  3999452.0  4030710.0  4025393.0  4059763.0  4149032.0
# 3     NaN   NaN  4047296.0  4079900.0  4071669.0  4106941.0  4192167.0
# 4     NaN   NaN       36.8       37.2       37.7       37.7       37.5
# ..    ...   ...        ...        ...        ...        ...        ...
# 795   NaN   NaN        NaN        NaN        NaN        NaN        NaN
# 796   NaN   NaN        NaN        NaN        NaN        NaN        NaN
# 797   NaN   NaN        NaN        NaN        NaN        NaN        NaN
# 798   NaN   NaN        NaN        NaN        NaN        NaN        NaN
# 799   NaN   NaN        NaN        NaN        NaN        NaN        NaN
#
#           2024  2025
# 0    8479314.0   NaN
# 1         10.6   NaN
# 2    4217861.0   NaN
# 3    4261453.0   NaN
# 4         37.5   NaN
# ..         ...   ...
# 795        NaN   NaN
# 796        NaN   NaN
# 797        NaN   NaN
# 798        NaN   NaN
# 799        NaN   NaN
#
# [800 rows x 15 columns]

# %% [markdown]
# ## Task 1: Data Cleaning - TODO

# %%
# clean data here

# %% [markdown]
# ## Task 1: Derived Statistics - TODO

# %% [markdown]
# ### Group member 1 SID: 520447042

# %%
#### Stat 1:

# %%
#### Stat 2:

# %%
#### Stat 3:

# %%
#### Stat 4:

# %%
#### Stat 5:

# %% [markdown]
# ### Group member 2 SID:

# %%
#### Stat 1:

# %%
#### Stat 2:

# %%
#### Stat 3:

# %%
#### Stat 4:

# %%
#### Stat 5:

# %% [markdown]
# ### Group member 3 SID:

# %%
#### Stat 1:

# %%
#### Stat 2:

# %%
#### Stat 3:

# %%
#### Stat 4:

# %%
#### Stat 5:

# %% [markdown]
# ### Group member 4 SID:

# %%
#### Stat 1:

# %%
#### Stat 2:

# %%
#### Stat 3:

# %%
#### Stat 4:

# %%
#### Stat 5:

# %% [markdown]
# # Task 2: API Data Collection - TO DO

# %% [markdown]
# ## Task 2: Load in NSW Points of Interest API - TO DO

# %% [markdown]
# ### Link to the API website: https://datasets.seed.nsw.gov.au/dataset/nsw-points-of-interest-poi

# %% [markdown]
# 1. isolate an area box using longtitude and latitude
# 2. Find all POIs in chosen area
# 3. do analysis (check all these as i am doing this from memory)

# %% [markdown]
# ## Task 2: Develop Function - TO DO

# %% [markdown]
# ## Task 2: Build Loop - TO DO

# %% [markdown]
# ## Task 2: Add results to Database - TO DO

# %% [markdown]
# # Task 3: Compute Scores - TO DO

# %% [markdown]
# # Task 4: Prepare Report - TO DO

# %% [markdown]
# # Task 5: Brief Conversation with Tutor - TO DO

# %% [markdown]
# # Deliverables - TO DO

# %% [markdown]
# 1. PDF Report  - Google Doc: link in READ ME and : https://docs.google.com/document/d/1n2X06f8SsJrVs9xzTqE0d5J3EYx_cJwz28PFvmnBcf0/edit?usp=sharing
# 2. Juytper Notebook - THIS
# 3. Convo with tutor
